# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cols=[]
with open('/content/drive/MyDrive/kddcup.names', 'r') as f :
  #print(f.read())
  f.readline()
  for i in f.readlines():
    cols.append(i.split(':')[0].strip())
    #print(i)
cols.append('target')

# %%
print(cols)
# Out:
# ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'target']

# %%
attacks_types = dict()
attacks_types['normal'] ='normal'
with open("/content/drive/MyDrive/training_attack_types",'r') as f:
    #print(f.read())
    for i in f:
      a=i.rstrip().split(' ')
      #print(a.split(' '))
      if len(a) > 1 :
        attacks_types[a[0]] = a[1]
print(attacks_types)
# Out:
# {'normal': 'normal', 'back': 'dos', 'buffer_overflow': 'u2r', 'ftp_write': 'r2l', 'guess_passwd': 'r2l', 'imap': 'r2l', 'ipsweep': 'probe', 'land': 'dos', 'loadmodule': 'u2r', 'multihop': 'r2l', 'neptune': 'dos', 'nmap': 'probe', 'perl': 'u2r', 'phf': 'r2l', 'pod': 'dos', 'portsweep': 'probe', 'rootkit': 'u2r', 'satan': 'probe', 'smurf': 'dos', 'spy': 'r2l', 'teardrop': 'dos', 'warezclient': 'r2l', 'warezmaster': 'r2l'}

# %%
df = pd.read_csv('/content/drive/MyDrive/kddcup.data_10_percent.gz',names=cols)

df['Attack Type'] = df.target.apply(lambda r:attacks_types[r[:-1]])

df.head()
# Out:
#    duration protocol_type  ...   target Attack Type
# 0         0           tcp  ...  normal.      normal
# 1         0           tcp  ...  normal.      normal
# 2         0           tcp  ...  normal.      normal
# 3         0           tcp  ...  normal.      normal
# 4         0           tcp  ...  normal.      normal
#
# [5 rows x 43 columns]

# %%
df.shape
# Out:
# (494021, 43)

# %%
df['Attack Type'].value_counts()
# Out:
# dos       391458
# normal     97278
# probe       4107
# r2l         1126
# u2r           52
# Name: Attack Type, dtype: int64

# %%
df.dtypes
# Out:
# duration                         int64
# protocol_type                   object
# service                         object
# flag                            object
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_root                         int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# num_outbound_cmds                int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# ...

# %%
df.isna().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
df['logged_in'].value_counts().plot(kind="bar")

# %%
plt.figure(figsize=(20,10))
df['service'].value_counts().plot(kind="bar")

# %%
df['target'].value_counts().plot(kind="bar")

# %%
df['Attack Type'].value_counts().plot(kind="bar")

# %%
df.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'target', 'Attack Type'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))

sns.heatmap(df.corr())

# %%
df['num_outbound_cmds'].value_counts().plot(kind="bar")

# %%
df.drop(['num_root','srv_serror_rate','srv_rerror_rate','dst_host_srv_serror_rate','dst_host_serror_rate','dst_host_rerror_rate','is_host_login','num_outbound_cmds','dst_host_srv_rerror_rate','dst_host_same_srv_rate'], axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    duration protocol_type  ...   target Attack Type
# 0         0           tcp  ...  normal.      normal
# 1         0           tcp  ...  normal.      normal
# 2         0           tcp  ...  normal.      normal
#
# [3 rows x 33 columns]

# %%
df.shape
# Out:
# (494021, 33)

# %%
df['protocol_type'].value_counts()
# Out:
# icmp    283602
# tcp     190065
# udp      20354
# Name: protocol_type, dtype: int64

# %%
protocolmap = {'icmp':0,'tcp':1,'udp':2}
df['protocol_type'] = df['protocol_type'].map(protocolmap)

# %%
df.head(3)
# Out:
#    duration  protocol_type  ...   target Attack Type
# 0         0              1  ...  normal.      normal
# 1         0              1  ...  normal.      normal
# 2         0              1  ...  normal.      normal
#
# [3 rows x 33 columns]

# %%
df['flag'].value_counts()
# Out:
# SF        378440
# S0         87007
# REJ        26875
# RSTR         903
# RSTO         579
# SH           107
# S1            57
# S2            24
# RSTOS0        11
# S3            10
# OTH            8
# Name: flag, dtype: int64

# %%
flagmap = {'SF':0,'S0':1,'REJ':2,'RSTR':3,'RSTO':4,'SH':5 ,'S1':6 ,'S2':7,'RSTOS0':8,'S3':9 ,'OTH':10}
df['flag'] = df['flag'].map(flagmap)

# %%
df.head(3)
# Out:
#    duration  protocol_type  ...   target  Attack Type
# 0         0              1  ...  normal.       normal
# 1         0              1  ...  normal.       normal
# 2         0              1  ...  normal.       normal
#
# [3 rows x 33 columns]

# %%
df.drop('service',axis = 1,inplace= True)

# %%
df
# Out:
#         duration  protocol_type  ...   target  Attack Type
# 0              0              1  ...  normal.       normal
# 1              0              1  ...  normal.       normal
# 2              0              1  ...  normal.       normal
# 3              0              1  ...  normal.       normal
# 4              0              1  ...  normal.       normal
# ...          ...            ...  ...      ...          ...
# 494016         0              1  ...  normal.       normal
# 494017         0              1  ...  normal.       normal
# 494018         0              1  ...  normal.       normal
# 494019         0              1  ...  normal.       normal
# 494020         0              1  ...  normal.       normal
#
# [494021 rows x 32 columns]

# %%
df.dtypes
# Out:
# duration                         int64
# protocol_type                    int64
# flag                             int64
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# serror_rate                    float64
# rerror_rate                    float64
# same_srv_rate                  float64
# diff_srv_rate                  float64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score

# %%
df.drop(['target',], axis=1,inplace=True)

# %%
Y = df[['Attack Type']]
X = df.drop(['Attack Type',], axis=1)

# %%
sc = MinMaxScaler()
X = sc.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.35, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=10000)

# %%
model.fit(X_train,Y_train.values.ravel())
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
# Out:
# array(['dos', 'dos', 'dos', ..., 'dos', 'dos', 'dos'], dtype=object)

# %%
model.score(X_train,Y_train)
# Out:
# 0.9935100727781186

# %%
model.score(X_test,Y_test)
# Out:
# 0.9935688342933815
